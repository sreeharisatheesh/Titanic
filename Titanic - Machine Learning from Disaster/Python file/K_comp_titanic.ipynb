# %%
import pandas as pd

# %%
dfg = pd.read_csv('gender_submission.csv')
dfg
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         1
# 2            894         0
# 3            895         0
# 4            896         1
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         0
#
# [418 rows x 2 columns]

# %%
df_test = pd.read_csv("test.csv")
df_test
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
df_train = pd.read_csv("train.csv")
df_train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
dftest = df_test.merge(dfg, on='PassengerId',how='left')

# %%
dftrain  = df_train.merge(dfg, on='PassengerId',how='left')

# %%
dftrain
# Out:
#      PassengerId  Survived_x  Pclass  \
# 0              1           0       3
# 1              2           1       1
# 2              3           1       3
# 3              4           1       1
# 4              5           0       3
# ..           ...         ...     ...
# 886          887           0       2
# 887          888           1       1
# 888          889           0       3
# 889          890           1       1
# 890          891           0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %%
dftest
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked  \
# ...

# %%
df_train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
dftrain.Survived_y.value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
dftrain.dtypes
# Out:
# PassengerId      int64
# Survived_x       int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# Survived_y     float64
# dtype: object

# %%
dftrain.drop(['Fare','SibSp','Parch','Ticket','Cabin','Name','PassengerId','Survived_y'],axis=1,inplace=True)

# %%
dftrain
# Out:
#      Survived_x  Pclass     Sex   Age Embarked
# 0             0       3    male  22.0        S
# 1             1       1  female  38.0        C
# 2             1       3  female  26.0        S
# 3             1       1  female  35.0        S
# 4             0       3    male  35.0        S
# ..          ...     ...     ...   ...      ...
# 886           0       2    male  27.0        S
# 887           1       1  female  19.0        S
# 888           0       3  female   NaN        S
# 889           1       1    male  26.0        C
# 890           0       3    male  32.0        Q
#
# [891 rows x 5 columns]

# %%
dftest.drop(['Fare','SibSp','Parch','Ticket','Cabin','Name','PassengerId'],axis=1,inplace=True)

# %%
dftest
# Out:
#      Pclass     Sex   Age Embarked  Survived
# 0         3    male  34.5        Q         0
# 1         3  female  47.0        S         1
# 2         2    male  62.0        Q         0
# 3         3    male  27.0        S         0
# 4         3  female  22.0        S         1
# ..      ...     ...   ...      ...       ...
# 413       3    male   NaN        S         0
# 414       1  female  39.0        C         1
# 415       3    male  38.5        S         0
# 416       3    male   NaN        S         0
# 417       3    male   NaN        C         0
#
# [418 rows x 5 columns]

# %%
dftrain.rename(columns={'Survived_x':'Survived'},inplace=True)

# %%
dftrain
# Out:
#      Survived  Pclass     Sex   Age Embarked
# 0           0       3    male  22.0        S
# 1           1       1  female  38.0        C
# 2           1       3  female  26.0        S
# 3           1       1  female  35.0        S
# 4           0       3    male  35.0        S
# ..        ...     ...     ...   ...      ...
# 886         0       2    male  27.0        S
# 887         1       1  female  19.0        S
# 888         0       3  female   NaN        S
# 889         1       1    male  26.0        C
# 890         0       3    male  32.0        Q
#
# [891 rows x 5 columns]

# %%
dftrain.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age         177
# Embarked      2
# dtype: int64

# %%
dftrain.dropna(subset=['Embarked'],inplace=True)
dftrain['Age'].fillna(dftrain['Age'].mean(),inplace=True)
# Out:
# <ipython-input-29-aa4744fcb03c>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dftrain['Age'].fillna(dftrain['Age'].mean(),inplace=True)

# %%
dftrain.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Sex         0
# Age         0
# Embarked    0
# dtype: int64

# %%
dftest.isnull().sum()
# Out:
# Pclass       0
# Sex          0
# Age         86
# Embarked     0
# Survived     0
# dtype: int64

# %%
dftest['Age'].fillna(dftest['Age'].mean(),inplace=True)
# Out:
# <ipython-input-32-78de350bc6de>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dftest['Age'].fillna(dftest['Age'].mean(),inplace=True)

# %%
dftrain.dtypes
# Out:
# Survived      int64
# Pclass        int64
# Sex          object
# Age         float64
# Embarked     object
# dtype: object

# %%
dftrain.columns
# Out:
# Index(['Survived', 'Pclass', 'Sex', 'Age', 'Embarked'], dtype='object')

# %%
dftrain.Sex.value_counts()
# Out:
# Sex
# male      577
# female    312
# Name: count, dtype: int64

# %%
dftrain.Embarked.value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
dftrain['Sex'] = dftrain['Sex'].apply(lambda x:1 if x=='male' else 0 )
dftrain['Embarked'] = dftrain['Embarked'].apply(lambda x:1 if x=='S' else( 2 if x=='C' else 3))

# %%
dftrain
# Out:
#      Survived  Pclass  Sex  Age  Embarked
# 0           0       3    1   22         1
# 1           1       1    0   38         2
# 2           1       3    0   26         1
# 3           1       1    0   35         1
# 4           0       3    1   35         1
# ..        ...     ...  ...  ...       ...
# 886         0       2    1   27         1
# 887         1       1    0   19         1
# 888         0       3    0   30         1
# 889         1       1    1   26         2
# 890         0       3    1   32         3
#
# [889 rows x 5 columns]

# %%
dftrain.Age = dftrain.Age.apply(lambda x:round(x , 0))
dftrain.Age = dftrain.Age.apply(lambda x:int(x))

# %%
dftest['Sex'] = dftest['Sex'].apply(lambda x:1 if x=='male' else 0 )
dftest['Embarked'] = dftest['Embarked'].apply(lambda x:1 if x=='S' else( 2 if x=='C' else 3))

# %%
dftest.Age = dftest.Age.apply(lambda x:round(x , 0))
dftest.Age = dftest.Age.apply(lambda x:int(x))

# %%
dftest
# Out:
#      Pclass  Sex  Age  Embarked  Survived
# 0         3    1   34         3         0
# 1         3    0   47         1         1
# 2         2    1   62         3         0
# 3         3    1   27         1         0
# 4         3    0   22         1         1
# ..      ...  ...  ...       ...       ...
# 413       3    1   30         1         0
# 414       1    0   39         2         1
# 415       3    1   38         1         0
# 416       3    1   30         1         0
# 417       3    1   30         2         0
#
# [418 rows x 5 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dftrain.corr()
# Out:
#           Survived    Pclass       Sex       Age  Embarked
# Survived  1.000000 -0.335549 -0.541585 -0.075178  0.108669
# Pclass   -0.335549  1.000000  0.127741 -0.326720  0.043835
# Sex      -0.541585  0.127741  1.000000  0.089855 -0.118593
# Age      -0.075178 -0.326720  0.089855  1.000000  0.012124
# Embarked  0.108669  0.043835 -0.118593  0.012124  1.000000

# %%
sns.heatmap(dftrain.corr(),annot=True)
# Out:
# <Axes: >

# %%
###################### splitting the datasets
from sklearn.model_selection import train_test_split
X = dftrain.drop('Survived',axis=1)
y  = dftrain['Survived']
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.33,random_state = 42)

# %%
############## Machine learning model ##############
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
###############  accuracy_score and confusion_matrix ##########
from sklearn.metrics import accuracy_score,confusion_matrix

# %%
models_list = [LogisticRegression(),KNeighborsClassifier(),RandomForestClassifier(),SVC()]
for models in models_list:
  print(models)
  models.fit(X_train,y_train)
  predicted  = models.predict(X_test)
  print('accuracy score:',accuracy_score(y_test,predicted))
  print('confusion matrix:',confusion_matrix(y_test,predicted))
  print()
  print()
  print()
  print()
# Out:
# LogisticRegression()
# accuracy score: 0.7959183673469388
# confusion matrix: [[150  34]
#  [ 26  84]]
#
#
#
#
# KNeighborsClassifier()
# accuracy score: 0.7721088435374149
# confusion matrix: [[153  31]
#  [ 36  74]]
#
#
#
#
# RandomForestClassifier()
# accuracy score: 0.7993197278911565
# confusion matrix: [[154  30]
#  [ 29  81]]
#
#
#
#
# SVC()
# accuracy score: 0.6360544217687075
# confusion matrix: [[177   7]
#  [100  10]]

# %%
### RandomForestClassifier ##########
rf = RandomForestClassifier(n_estimators=100)
rf.fit(X_train,y_train)
accuracy_score(rf.predict(X_test),y_test)
# Out:
# 0.8027210884353742

# %%
############# naive_bayes ###############
from sklearn.naive_bayes import MultinomialNB , GaussianNB
print("MultinomialNB")
mnb = MultinomialNB()
mnb.fit(X_train,y_train)
print(accuracy_score(mnb.predict(X_test),y_test))

print("GaussanNB")
gnb = GaussianNB()
gnb.fit(X_train,y_train)
print(accuracy_score(gnb.predict(X_test),y_test))
# Out:
# MultinomialNB
# 0.717687074829932
# GaussanNB
# 0.7755102040816326

# %%
########### KNeighborClassifier #############3
knn = KNeighborsClassifier(n_neighbors = 3)
knn.fit(X_train,y_train)
print(accuracy_score(knn.predict(X_test),y_test))
# Out:
# 0.7585034013605442

# %%
from sklearn.tree import DecisionTreeClassifier
dtc = DecisionTreeClassifier(random_state = 20)
dtc.fit(X_train,y_train)
print(accuracy_score(dtc.predict(X_test),y_test))
# Out:
# 0.7993197278911565

# %%
######## LogisticRegression ###
'''
  logistc regression and decision tree giving an accuracy of around 79 , whereas RandomForestClassifier giving almost 80
'''
